# %% [markdown]
# <a href="https://colab.research.google.com/github/Taka0007/PRML/blob/main/code/PRML(fig).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import random
# %matplotlib inline

# %% [markdown]
# ### 図1.2

# %%
x = np.linspace(0, 1, 100)
y = np.sin(2 * math.pi * x)
plt.plot(x, y, label='Graph')
plt.grid(True)
x_point = 0.0
for i in range(10):
    y_point = np.sin(2 * math.pi * x_point) + random.uniform(-0.2, 0.2)
    plt.scatter(x_point, y_point, c='red', label='Points', alpha=0.5)
    x_point += 0.1
plt.show()
